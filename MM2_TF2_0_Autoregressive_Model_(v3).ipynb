# %% [markdown]
# <a href="https://colab.research.google.com/github/mits-ds/Udemy_TF2/blob/main/MM2_TF2_0_Autoregressive_Model_(v3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install TensorFlow
# !pip install -q tensorflow-gpu==2.0.0-beta1

try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.
# 2.8.2

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make the original data
series = np.sin(0.1*np.arange(200)) + np.random.randn(200)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T)
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (190, 10) Y.shape (190,)

# %%
### try autoregressive linear model
i = Input(shape=(T,))
x = Dense(1)(i)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(lr=0.1),
)

# train the RNN
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=80,
  validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/80
# 3/3 [==============================] - 1s 77ms/step - loss: 1.4683 - val_loss: 0.2533
# Epoch 2/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6936 - val_loss: 0.7190
# Epoch 3/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6117 - val_loss: 0.1853
# Epoch 4/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1118 - val_loss: 0.1767
# Epoch 5/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2994 - val_loss: 0.2154
# Epoch 6/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2182 - val_loss: 0.0599
# Epoch 7/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0500 - val_loss: 0.1337
# Epoch 8/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1284 - val_loss: 0.1183
# Epoch 9/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0789 - val_loss: 0.0424
# Epoch 10/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0456 - val_loss: 0.0959
# Epoch 11/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0794 - val_loss: 0.0820
# Epoch 12/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0460 - val_loss: 0.0445
# Epoch 13/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0400 - val_loss: 0.0556
# Epoch 14/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0477 - val_loss: 0.0426
# Epoch 15/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0307 - val_loss: 0.0414
# Epoch 16/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0391 - val_loss: 0.0430
# Epoch 17/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0317 - val_loss: 0.0369
# Epoch 18/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0292 - val_loss: 0.0442
# Epoch 19/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0332 - val_loss: 0.0358
# Epoch 20/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0269 - val_loss: 0.0378
# Epoch 21/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0282 - val_loss: 0.0360
# Epoch 22/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0259 - val_loss: 0.0345
# Epoch 23/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0253 - val_loss: 0.0345
# Epoch 24/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0247 - val_loss: 0.0335
# Epoch 25/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0240 - val_loss: 0.0333
# Epoch 26/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0239 - val_loss: 0.0328
# Epoch 27/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0232 - val_loss: 0.0326
# Epoch 28/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0227 - val_loss: 0.0320
# Epoch 29/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0225 - val_loss: 0.0317
# Epoch 30/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0220 - val_loss: 0.0313
# Epoch 31/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0218 - val_loss: 0.0310
# Epoch 32/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0217 - val_loss: 0.0307
# Epoch 33/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0215 - val_loss: 0.0303
# Epoch 34/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0211 - val_loss: 0.0304
# Epoch 35/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0208 - val_loss: 0.0300
# Epoch 36/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0204 - val_loss: 0.0294
# Epoch 37/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0204 - val_loss: 0.0291
# Epoch 38/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0200 - val_loss: 0.0288
# Epoch 39/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0198 - val_loss: 0.0285
# Epoch 40/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0194 - val_loss: 0.0282
# Epoch 41/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0192 - val_loss: 0.0279
# Epoch 42/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0192 - val_loss: 0.0278
# Epoch 43/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0187 - val_loss: 0.0274
# Epoch 44/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0187 - val_loss: 0.0272
# Epoch 45/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0183 - val_loss: 0.0269
# Epoch 46/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0184 - val_loss: 0.0268
# Epoch 47/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0181 - val_loss: 0.0264
# Epoch 48/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0180 - val_loss: 0.0261
# Epoch 49/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0174 - val_loss: 0.0259
# Epoch 50/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0176 - val_loss: 0.0257
# Epoch 51/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0171 - val_loss: 0.0254
# Epoch 52/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0176 - val_loss: 0.0254
# Epoch 53/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0171 - val_loss: 0.0251
# Epoch 54/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0170 - val_loss: 0.0246
# Epoch 55/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0164 - val_loss: 0.0244
# Epoch 56/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0242
# Epoch 57/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0166 - val_loss: 0.0239
# Epoch 58/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.0237
# Epoch 59/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0161 - val_loss: 0.0237
# Epoch 60/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0160 - val_loss: 0.0233
# Epoch 61/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0158 - val_loss: 0.0232
# Epoch 62/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0161 - val_loss: 0.0230
# Epoch 63/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0158 - val_loss: 0.0227
# Epoch 64/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0158 - val_loss: 0.0228
# Epoch 65/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0155 - val_loss: 0.0223
# Epoch 66/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0152 - val_loss: 0.0223
# Epoch 67/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0151 - val_loss: 0.0220
# Epoch 68/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0150 - val_loss: 0.0219
# Epoch 69/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.0217
# Epoch 70/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0151 - val_loss: 0.0216
# Epoch 71/80
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0150 - val_loss: 0.0215
# Epoch 72/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0148 - val_loss: 0.0213
# Epoch 73/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0146 - val_loss: 0.0211
# Epoch 74/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0146 - val_loss: 0.0209
# Epoch 75/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0148 - val_loss: 0.0212
# Epoch 76/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0145 - val_loss: 0.0207
# Epoch 77/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0206
# Epoch 78/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0142 - val_loss: 0.0205
# Epoch 79/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0144 - val_loss: 0.0203
# Epoch 80/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0144 - val_loss: 0.0202

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1))[0,0] # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# first validation input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1))[0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p)
  
  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
